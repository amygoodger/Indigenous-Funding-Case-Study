# %% [markdown]
# # Guardian API access

# %%
#import required libraries
import requests
import json
import re
import time

# %%
#load your personal API key
file_path = file_path = "../../private/guardian_key.txt"
with open(file_path, 'r') as file:
    key = file.read().strip()
len(key)
# Out:
# 36

# %%
#build a search URL
base_url = 'https://content.guardianapis.com/'
search_string = "(indigenous%20OR%20first%20nations%20OR%20aboriginal)%20AND%20government%20AND%20(policy%20OR%20initiative%20OR%20program%20OR%20funding%20OR%20aid%20OR%20assistance)%20AND%20(economy%20OR%20innovation%20OR%20job%20creation%20OR%20employment)%20AND%20(boost%20OR%20grow%20OR%20increase%20OR%20build%20OR%20create%20OR%20develop)"
production_office = "aus"
from_date = "2015-01-01"

full_url = base_url+f"search?q={search_string}&production-office={production_office}&from-date={from_date}&show-fields=body&api-key={key}"

print(full_url)
# Out:
# https://content.guardianapis.com/search?q=(indigenous%20OR%20first%20nations%20OR%20aboriginal)%20AND%20government%20AND%20(policy%20OR%20initiative%20OR%20program%20OR%20funding%20OR%20aid%20OR%20assistance)%20AND%20(economy%20OR%20innovation%20OR%20job%20creation%20OR%20employment)%20AND%20(boost%20OR%20grow%20OR%20increase%20OR%20build%20OR%20create%20OR%20develop)&production-office=aus&from-date=2015-01-01&show-fields=body&api-key=78c5d4a1-1677-4424-8a0e-2019f74b3fcd

# %%
# get data from server
server_response = requests.get(full_url)
server_data = server_response.json()
resp_data = server_data.get('response','')
if resp_data == '':
    print("ERROR obtaining results:",server_data)
else:
    print("SUCCESS!")
    print(f"{resp_data['total']} results found available in {resp_data['pages']} pages")
    print(f"{resp_data['pageSize']} results per page")
    results = resp_data.get('results',[])
# Out:
# SUCCESS!
# 110 results found available in 11 pages
# 10 results per page

# %%
results[0]
# Out:
# {'id': 'australia-news/live/2023/sep/14/australia-politics-live-qantas-yes-voice-smoke-sydney-greens-federal-funding-schools-covid-cruise-ship',
#  'type': 'liveblog',
#  'sectionId': 'australia-news',
#  'sectionName': 'Australia news',
#  'webPublicationDate': '2023-09-14T08:17:23Z',
#  'webTitle': 'Developer ‘deeply regrets’ comments – as it happened',
#  'webUrl': 'https://www.theguardian.com/australia-news/live/2023/sep/14/australia-politics-live-qantas-yes-voice-smoke-sydney-greens-federal-funding-schools-covid-cruise-ship',
#  'apiUrl': 'https://content.guardianapis.com/australia-news/live/2023/sep/14/australia-politics-live-qantas-yes-voice-smoke-sydney-greens-federal-funding-schools-covid-cruise-ship',
#  'fields': {'body': '<div id="block-6502bbdd8f0873945374f430" class="block is-summary" data-block-contributor=""> <p class="block-time published-time"> <time datetime="2023-09-14T08:06:13.346Z">9.06am <span class="timezone">BST</span></time> </p>   <h2 class="block-title">What we learned today, Thursday 14 September</h2>  <div class="block-elements">  <p>And that’s where we’ll wrap up today. Thanks so much for your company.</p> <p>Here’s a little of what we learned:</p> <ul> <li><p><strong>Jacinta Nampijinpa Price</strong> <a href="https://www.theguardian.com/australia-news/2023/sep/14/jacinta-nampijinpa-price-says-colonisation-had-no-negative-impacts-on-indigenous-australians">has said there are no negative ongoing</a> impacts of British colonisation on Indigenous Australians, dismissing concerns about intergenerational trauma. <strong>Linda Burney</strong> called the comments “offensive”.</p></li> <li><p>A Senate inquiry into Victoria’s cancellation of the 2026 Commonwealth Games has recommended <a href="https://www.theguardian.com/australia-news/live/2023/sep/14/australia-politics-live-qantas-yes-voice-smoke-sydney-greens-federal-funding-schools-covid-cruise-ship?filterKeyEvents=false&amp;page=with:block-6502a9878f08cf50e1614832#block-6502a9878f08cf50e1614832">the federal government urgently intervene</a> to save the event.</p></li> <li><p>An inquiry report into Australia’s consent laws found <a href="https://www.theguardian.com/australia-news/live/2023/sep/14/australia-politics-live-qantas-yes-voice-smoke-sydney-greens-federal-funding-schools-covid-cruise-ship?filterKeyEvents=false&amp;page=with:block-65029f1b8f0893e8a8a02bdd#block-65029f1b8f0893e8a8a02bdd">university students who have experienced sexual violence are being significantly re-traumatised</a> by the treatment of their university.</p></li> <li><p>Employers hired almost <a href="https://www.theguardian.com/business/2023/sep/14/australian-economy-august-jobs-numbers-increase">65,000 more workers in August</a>, many more than expected, improving the prospects that the economy will avoid a hard landing but also raising the possibility the Reserve Bank may hike interest rates again.</p></li> <li><p>The millionaire property developer <strong><a href="https://www.theguardian.com/australia-news/2023/sep/14/tim-gurner-group-insensitive-unemployment-increase-comments-apology-economy">Tim Gurner</a></strong><a href="https://www.theguardian.com/australia-news/2023/sep/14/tim-gurner-group-insensitive-unemployment-increase-comments-apology-economy"> says he deeply regrets the comments he made</a> suggesting Australia needs unemployment to increase by 40% to 50%.</p></li> <li><p><a href="https://www.theguardian.com/australia-news/live/2023/sep/14/australia-politics-live-qantas-yes-voice-smoke-sydney-greens-federal-funding-schools-covid-cruise-ship?filterKeyEvents=false&amp;page=with:block-6502301d8f0873945374f082#block-6502301d8f0873945374f082">Full-scale strikes at Chevron’s liquefied natural gas facilities</a> in Australia started this morning, putting global energy markets on edge amid a protracted industrial dispute.</p></li> <li><p>Former Australian defence force members who work for foreign military organisations without approval from the Australian government <a href="https://www.theguardian.com/australia-news/live/2023/sep/14/australia-politics-live-qantas-yes-voice-smoke-sydney-greens-federal-funding-schools-covid-cruise-ship?filterKeyEvents=false&amp;page=with:block-65022b058f0893e8a8a028d4#block-65022b058f0893e8a8a028d4">face up to 20 years in jail</a> under proposed new laws.</p></li> <li><p>And the AFL great <strong>Michael Long</strong> <a href="https://www.theguardian.com/australia-news/2023/sep/14/indigenous-voice-to-parliament-referendum-long-walk-to-canberr">completed his long walk to Canberra</a> in support of the Indigenous voice.</p></li> </ul> </div>   <p class="block-time updated-time">Updated <time datetime="2023-09-14T09:14:24.703Z">at 10.14am BST</ti ...
#  'isHosted': False,
#  'pillarId': 'pillar/news',
#  'pillarName': 'News'}

# %%
num_pages = resp_data['pages']
num_pages
# Out:
# 11

# %%
def articles_from_page_results(page_results):
    articles = {}
    for result in page_results:
        article_date = result['webPublicationDate']
        article_title = result['webTitle']+f" [{article_date}]"
        article_html = result['fields']['body']
        article_text = re.sub(r'<.*?>','',article_html)
        articles[article_title] = article_text
    return articles

# %%
def get_all_articles_for_response(response_json,full_url):
    total_pages = response_json['pages']
    total_articles = response_json['total']
    print(f"Fetching {total_articles} articles from {total_pages} pages...")
    all_articles = {}
    page1_articles = articles_from_page_results(response_json['results'])
    all_articles.update(page1_articles)
    print("Added articles for page: 1")
    
    for page in range(2,total_pages+1):
        print("Getting articles from API for page:",page)
        page_response = requests.get(full_url+f"&page={page}")
        page_data = page_response.json()['response']
        print("Processing results for page:",page_data['currentPage'])
        page_articles = articles_from_page_results(page_data['results'])
        print(f"Fetched {len(page_articles)} articles.")
        all_articles.update(page_articles)
        print("Added articles for page:",page)
        print(f"Status: {len(all_articles)} articles.")
        time.sleep(1) # make sure we're not hitting the API to hard
    
    print(f"FINISHED: Fetched {len(all_articles)} articles.")
    return all_articles

# %%
my_articles = get_all_articles_for_response(resp_data,full_url)
# Out:
# Fetching 110 articles from 11 pages...
# Added articles for page: 1
# Getting articles from API for page: 2
# Processing results for page: 2
# Fetched 10 articles.
# Added articles for page: 2
# Status: 20 articles.
# Getting articles from API for page: 3
# Processing results for page: 3
# Fetched 10 articles.
# Added articles for page: 3
# Status: 30 articles.
# Getting articles from API for page: 4
# Processing results for page: 4
# Fetched 10 articles.
# Added articles for page: 4
# Status: 40 articles.
# Getting articles from API for page: 5
# Processing results for page: 5
# Fetched 10 articles.
# Added articles for page: 5
# Status: 50 articles.
# Getting articles from API for page: 6
# Processing results for page: 6
# Fetched 10 articles.
# Added articles for page: 6
# Status: 60 articles.
# Getting articles from API for page: 7
# Processing results for page: 7
# Fetched 10 articles.
# Added articles for page: 7
# Status: 70 articles.
# Getting articles from API for page: 8
# Processing results for page: 8
# Fetched 10 articles.
# Added articles for page: 8
# Status: 80 articles.
# Getting articles from API for page: 9
# Processing results for page: 9
# Fetched 10 articles.
# Added articles for page: 9
# Status: 90 articles.
# Getting articles from API for page: 10
# Processing results for page: 10
# Fetched 10 articles.
# Added articles for page: 10
# Status: 100 articles.
# Getting articles from API for page: 11
# Processing results for page: 11
# Fetched 10 articles.
# Added articles for page: 11
# Status: 110 articles.
# FINISHED: Fetched 110 articles.

# %%
print("Total Articles:",len(my_articles))
for title,text in my_articles.items():
    print(title)
# Out:
# Total Articles: 110
# Developer ‘deeply regrets’ comments – as it happened [2023-09-14T08:17:23Z]
# Bob Carr urges New Zealand not to join Aukus – as it happened [2024-04-17T08:12:08Z]
# Treasurer delivers budget speech – as it happened [2024-05-14T11:55:11Z]
# Dutton delivers federal budget reply speech – as it happened [2024-05-16T10:54:54Z]
# Premier defends Games compensation; Black Lives Matter rally in Sydney – as it happened [2023-08-19T07:22:42Z]
# Indigenous group condemns Jacinta Nampijinpa Price’s ‘denial of history’ – as it happened [2023-09-20T08:26:46Z]
# Vast Aukus spending sparks calls to boost Australia’s aid budget [2023-03-29T14:00:40Z]
# David Shoebridge says Julian Assange ‘may not survive’ trial and extradition – as it happened [2024-03-21T06:53:15Z]
# ALP national conference day 2 – as it happened [2023-08-18T06:36:34Z]
# Hastie’s defence comments ‘unhinged and misleading’, Conroy says – as it happened [2024-02-20T07:18:38Z]
# Everyone on Newstart should be able to get a job, says minister, despite increase in some areas [2019-08-12T04:12:59Z]
# Guardian Australia wins Judith Neilson Institute funding for Pacific editor [2019-07-16T23:58:29Z]
# Victoria records 76 new Covid cases, NSW reports nine and Qld eight as 1m jobs lost – as it happened [2020-09-09T09:28:12Z]
# 'Stop Adani': protester disrupts opening of parliament – as it happened [2019-07-02T07:42:24Z]
# Brazil death toll exceeds 60,000; West Bank goes into lockdown – as it happened [2020-07-01T23:39:49Z]
# Scott Morrison announces South Korea travel ban as part of extended coronavirus response – as it happened [2020-03-05T06:19:46Z]
# Labor fails to commit to Newstart increase despite promising voters a 'fair go' – as it happened [2018-12-16T07:14:16Z]
# Labor conference: Peter Dutton says refugee measures 'nothing but subterfuge' – as it happened [2018-12-17T07:27:27Z]
# Bill Shorten and Scott Morrison appear in first televised debate – as it happened [2019-04-29T10:45:46Z]
# US Covid-19 death toll passes 75,000 – as it happened [2020-05-07T23:58:24Z]
# Aged care gets $1.6bn in budget package for older Australians and pension bonus increase [2018-05-08T10:17:01Z]
# Pauline Hanson's One Nation says it will back Coalition's corporate tax cuts – as it happened [2018-03-22T05:40:29Z]
# Labor alleges 'secret deal' with One Nation over tax cuts – as it happened [2018-05-22T07:42:32Z]
# Coalition promises $30m for Indigenous rangers and says it will create new jobs [2017-05-17T08:18:41Z]
# Landcare funding boost to include $15m for new Indigenous protected areas [2017-03-26T20:51:21Z]
# Labor targets Turnbull over penalty rates as Shorten defends union record – as it happened [2018-06-25T07:04:51Z]
# The big book about small town Australia that travelled the world [2017-09-07T18:00:16Z]
# Unemployed people need money to live on. That’s a fact, Mr Porter. Not hard to imagine | Cassandra Goldie [2016-10-03T03:14:52Z]
# Turnbull's jobs plan will boost national income by just 0.6%, says Grattan Institute [2016-05-12T20:00:07Z]
# Domestic violence experts welcome $100m boost, but say more is needed [2015-09-24T05:59:28Z]
# Crocodile eggs and 3D printing: could these be champions of the Top End's Indigenous communities? [2015-11-03T05:47:29Z]
# Election campaign day 19 – as it happened [2016-05-27T06:04:41Z]
# Malcolm Turnbull stands by superannuation changes - as it happened [2016-06-02T08:06:33Z]
# Global Warning: 24 hours on the climate change frontline as Trump becomes president – as it happened [2017-01-20T07:09:51Z]
# Labor targets Malcolm Turnbull over negative gearing – as it happened [2016-02-25T06:30:08Z]
# Victoria allocates $4m to help growing number of domestic violence victims [2015-07-07T04:36:03Z]
# Budget blowout, offshore processing and building watchdog - as it happened [2016-02-03T06:12:03Z]
# Campaign as it happened: Turnbull and Shorten launch counter bids on manufacturing [2016-05-16T08:05:40Z]
# Labor builds the pressure over marriage equality – politics live [2015-10-22T05:59:00Z]
# Turnbull seeks advice on whether Stuart Robert breached ministerial standards – politics live [2016-02-08T06:43:28Z]
# Employers to be offered cash to place jobseekers in roles lasting only a month [2015-03-31T04:31:57Z]
# Intergenerational report, Ricky Muir's first speech, higher education – as it happened [2015-03-05T07:39:33Z]

# %%
with open(f"indigenous_articles.json",'w', encoding='utf-8') as fp:
    fp.write(json.dumps(my_articles))
